# %%
from artist_finder import Finder

# %%
ids = ["0oSGxfWSnnOXhD2fKuz2Gy",  # david bowie
       "4yBBNmdvVaoPEnr2lt14q7"]  # faust

# %%
finder = Finder(*ids)

# %%
finder.grow_and_plot()
# Out:
# Nodes (initial): 311
# Nodes (post-first-trim): 153
# Nodes (post-paths-trim): 8
# (<Figure size 1152x648 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x23489733808>)
